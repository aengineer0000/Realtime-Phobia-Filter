# %%
from ultralytics import YOLOWorld


# 1. Load the pre-trained YOLO-World model
# Using 's' (small) for speed, but you can use 'm' or 'l' for higher accuracy
model = YOLOWorld('yolov8s-worldv2.pt')

# 2. Define your Phobia Vocabulary
# Pro-tip: Use descriptive nouns (e.g., "wasp" instead of just "bug") 
# to help the vision-language model.
phobia_classes = ["arachnid-spider", "insect" "reptile-snake", "needle"]
model.set_classes(phobia_classes)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/aadit/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# requirements: Ultralytics requirement ['git+https://github.com/ultralytics/CLIP.git'] not found, attempting AutoUpdate...
# ...
#   Cloning https://github.com/ultralytics/CLIP.git to /tmp/pip-req-build-foxjyhws
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/CLIP.git /tmp/pip-req-build-foxjyhws
#   Resolved https://github.com/ultralytics/CLIP.git to commit 88ade288431a46233f1556d1e141901b3ef0a36b
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="iCrwFlT1oieCY1kRh8IL")
project = rf.workspace("roboflow-100").project("insects-mytwu")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 395.6 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 766.2 kB/s eta 0:00:000:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 2.2 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 671.2 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 661.7 kB/s eta 0:00:000:00:01
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to insects-2 in yolov8:: 100%|██████████| 2002/2002 [00:00<00:00, 5084.22it/s]

# %%
# 3. Path to your test images
img_path = 'insects-2/test/images/4_jpg.rf.3d638f6579ef2dd8297910f10276cb3b.jpg'
results = model.predict(img_path, imgsz=224)
results[0].show()
# Out:
# image 1/1 /home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/test/images/4_jpg.rf.3d638f6579ef2dd8297910f10276cb3b.jpg: 224x224 (no detections), 4633.9ms
# Speed: 213.6ms preprocess, 4633.9ms inference, 57.4ms postprocess per image at shape (1, 3, 224, 224)
# <PIL.Image.Image image mode=RGB size=224x224>
