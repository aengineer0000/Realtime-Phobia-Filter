# %%
import wandb # KEY: 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
from ultralytics import YOLOWorld
import torch


# 1. Initialize W&B project
wandb.init(project="phobia-detector-yoloworld", job_type="training")

# 2. Load the YOLO-World model
# Using 'v2' models is highly recommended for custom training
model = YOLOWorld('yolov8s-worldv2.pt')

# 3. Fine-tune
# The 'data' parameter points to the data.yaml file provided by Roboflow
try:
    device = 'xpu' if torch.xpu.is_available() else 'cpu'
except ImportError:
    device = 'cpu'

print(f"Using device: {device}")

model.train(
    data='insects-2/data.yaml',
    epochs=15,
    patience=5,
    imgsz=224,
    batch=-1,
    device=device,      
    project="phobia-detector",
    name="insect_finetune",
    freeze=10,
    lr0=0.01,
    plots=True,
    mosaic=0.0,        # OFF: Don't combine 4 images into one (bad for small 224px imgs)
    mixup=0.0,         # OFF: Don't blend two images
    fliplr=0.5,        # ON: Random horizontal flip (insects look the same either way)
    flipud=0.0,        # OFF: Usually insects aren't seen upside down unless dead
    hsv_h=0.015,       # ON: Very slight color hue shift
    hsv_s=0.7,         # ON: Saturation shift
    hsv_v=0.4,         # ON: Brightness shift (helps with indoor/outdoor lighting)
    degrees=0.0,       # OFF: No rotation for this quick test
    scale=0.5,         # ON: Random zoom in/out to handle distance
    translate=0.1
)

# 4. Finish the W&B run
wandb.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">twilight-surf-2</strong> at: <a href='https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld/runs/dv2rsrcg' target="_blank">https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld/runs/dv2rsrcg</a><br> View project at: <a href='https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld' target="_blank">https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260313_145257-dv2rsrcg/logs</code>
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/home/aadit/FAI/final/Realtime-Phobia-Filter/wandb/run-20260313_150543-79n6m682</code>
# Syncing run <strong><a href='https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld/runs/79n6m682' target="_blank">fanciful-silence-3</a></strong> to <a href='https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld' target="_blank">https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld</a>
#  View run at <a href='https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld/runs/79n6m682' target="_blank">https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld/runs/79n6m682</a>
# Using device: cpu
# Ultralytics 8.4.21 🚀 Python-3.12.3 torch-2.10.0+cu128 CPU (Intel Core Ultra 7 256V)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=insects-2/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=15, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=10, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s-worldv2.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=insect_finetune, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=phobia-detector, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/aadit/FAI/final/Realtime-Phobia-Filter/runs/detect/phobia-detector/insect_finetune, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/aadit/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 1.0MB/s 0.7ss 0.7s<0.0ss
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    837508  ultralytics.nn.modules.block.C2fAttn         [768, 256, 1, 128, 4]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    226242  ultralytics.nn.modules.block.C2fAttn         [384, 128, 1, 64, 2]
#  16                  15  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    739204  ultralytics.nn.modules.block.C2fAttn         [384, 256, 1, 128, 4]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   2821896  ultralytics.nn.modules.block.C2fAttn         [768, 512, 1, 256, 8]
#  22        [15, 18, 21]  1   2317270  ultralytics.nn.modules.head.WorldDetect      [10, 512, True, 16, None, [128, 256, 512]]
# YOLOv8s-worldv2 summary: 149 layers, 12,759,880 parameters, 12,759,864 gradients, 34.5 GFLOPs
#
# Transferred 409/412 items from pretrained weights
# Freezing layer 'model.0.conv.weight'
# Freezing layer 'model.0.bn.weight'
# Freezing layer 'model.0.bn.bias'
# Freezing layer 'model.1.conv.weight'
# Freezing layer 'model.1.bn.weight'
# Freezing layer 'model.1.bn.bias'
# Freezing layer 'model.2.cv1.conv.weight'
# Freezing layer 'model.2.cv1.bn.weight'
# Freezing layer 'model.2.cv1.bn.bias'
# Freezing layer 'model.2.cv2.conv.weight'
# Freezing layer 'model.2.cv2.bn.weight'
# Freezing layer 'model.2.cv2.bn.bias'
# Freezing layer 'model.2.m.0.cv1.conv.weight'
# Freezing layer 'model.2.m.0.cv1.bn.weight'
# Freezing layer 'model.2.m.0.cv1.bn.bias'
# Freezing layer 'model.2.m.0.cv2.conv.weight'
# Freezing layer 'model.2.m.0.cv2.bn.weight'
# Freezing layer 'model.2.m.0.cv2.bn.bias'
# Freezing layer 'model.3.conv.weight'
# Freezing layer 'model.3.bn.weight'
# Freezing layer 'model.3.bn.bias'
# Freezing layer 'model.4.cv1.conv.weight'
# Freezing layer 'model.4.cv1.bn.weight'
# Freezing layer 'model.4.cv1.bn.bias'
# Freezing layer 'model.4.cv2.conv.weight'
# Freezing layer 'model.4.cv2.bn.weight'
# Freezing layer 'model.4.cv2.bn.bias'
# Freezing layer 'model.4.m.0.cv1.conv.weight'
# Freezing layer 'model.4.m.0.cv1.bn.weight'
# Freezing layer 'model.4.m.0.cv1.bn.bias'
# Freezing layer 'model.4.m.0.cv2.conv.weight'
# Freezing layer 'model.4.m.0.cv2.bn.weight'
# Freezing layer 'model.4.m.0.cv2.bn.bias'
# Freezing layer 'model.4.m.1.cv1.conv.weight'
# Freezing layer 'model.4.m.1.cv1.bn.weight'
# Freezing layer 'model.4.m.1.cv1.bn.bias'
# Freezing layer 'model.4.m.1.cv2.conv.weight'
# Freezing layer 'model.4.m.1.cv2.bn.weight'
# Freezing layer 'model.4.m.1.cv2.bn.bias'
# Freezing layer 'model.5.conv.weight'
# Freezing layer 'model.5.bn.weight'
# Freezing layer 'model.5.bn.bias'
# Freezing layer 'model.6.cv1.conv.weight'
# Freezing layer 'model.6.cv1.bn.weight'
# Freezing layer 'model.6.cv1.bn.bias'
# Freezing layer 'model.6.cv2.conv.weight'
# Freezing layer 'model.6.cv2.bn.weight'
# Freezing layer 'model.6.cv2.bn.bias'
# Freezing layer 'model.6.m.0.cv1.conv.weight'
# Freezing layer 'model.6.m.0.cv1.bn.weight'
# Freezing layer 'model.6.m.0.cv1.bn.bias'
# Freezing layer 'model.6.m.0.cv2.conv.weight'
# Freezing layer 'model.6.m.0.cv2.bn.weight'
# Freezing layer 'model.6.m.0.cv2.bn.bias'
# Freezing layer 'model.6.m.1.cv1.conv.weight'
# Freezing layer 'model.6.m.1.cv1.bn.weight'
# Freezing layer 'model.6.m.1.cv1.bn.bias'
# Freezing layer 'model.6.m.1.cv2.conv.weight'
# Freezing layer 'model.6.m.1.cv2.bn.weight'
# Freezing layer 'model.6.m.1.cv2.bn.bias'
# Freezing layer 'model.7.conv.weight'
# Freezing layer 'model.7.bn.weight'
# Freezing layer 'model.7.bn.bias'
# Freezing layer 'model.8.cv1.conv.weight'
# Freezing layer 'model.8.cv1.bn.weight'
# Freezing layer 'model.8.cv1.bn.bias'
# Freezing layer 'model.8.cv2.conv.weight'
# Freezing layer 'model.8.cv2.bn.weight'
# Freezing layer 'model.8.cv2.bn.bias'
# Freezing layer 'model.8.m.0.cv1.conv.weight'
# Freezing layer 'model.8.m.0.cv1.bn.weight'
# Freezing layer 'model.8.m.0.cv1.bn.bias'
# Freezing layer 'model.8.m.0.cv2.conv.weight'
# Freezing layer 'model.8.m.0.cv2.bn.weight'
# Freezing layer 'model.8.m.0.cv2.bn.bias'
# Freezing layer 'model.9.cv1.conv.weight'
# Freezing layer 'model.9.cv1.bn.weight'
# Freezing layer 'model.9.cv1.bn.bias'
# Freezing layer 'model.9.cv2.conv.weight'
# Freezing layer 'model.9.cv2.bn.weight'
# Freezing layer 'model.9.cv2.bn.bias'
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 2.4±3.5 ms, read: 2.8±3.9 MB/s, size: 7.6 KB)
# train: Scanning /home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/train/labels... 696 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 696/696 174.9it/s 4.0s0.1s
# train: New cache created: /home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/train/labels.cache
# Caching text embeddings to '/home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/train/text_embeddings_clip_ViT-B_32.pt'
# AutoBatch: Computing optimal batch size for imgsz=224 at 60.0% CUDA memory utilization.
# WARNING ⚠️ AutoBatch: intended for CUDA devices, using default batch-size 16
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 26.2±18.3 MB/s, size: 9.0 KB)
# train: Scanning /home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/train/labels.cache... 696 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 696/696 116.8Mit/s 0.0s
# Reading existed cache from '/home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/train/text_embeddings_clip_ViT-B_32.pt'
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2.8±1.7 MB/s, size: 11.5 KB)
# val: Scanning /home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/valid/labels... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 493.4it/s 0.4s0.1s
# val: New cache created: /home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 67 weight(decay=0.0), 72 weight(decay=0.0005), 81 bias(decay=0.0)
# Plotting labels to /home/aadit/FAI/final/Realtime-Phobia-Filter/runs/detect/phobia-detector/insect_finetune/labels.jpg...
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /home/aadit/FAI/final/Realtime-Phobia-Filter/runs/detect/phobia-detector/insect_finetune
# Starting training for 15 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/15         0G      1.218       2.68       1.44          8        224: 100% ━━━━━━━━━━━━ 44/44 2.1s/it 1:320.9sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.0s/it 14.3s1.8s
#                    all        199        204       0.49      0.466      0.492      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/15         0G      1.132      1.503      1.382          8        224: 100% ━━━━━━━━━━━━ 44/44 1.1it/s 41.9s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.2s1.1ss
#                    all        199        204      0.564      0.669      0.644        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/15         0G      1.142      1.216      1.378          8        224: 100% ━━━━━━━━━━━━ 44/44 1.1it/s 38.9s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.6s1.2ss
#                    all        199        204      0.664      0.656      0.725      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/15         0G      1.065       1.09      1.302          8        224: 100% ━━━━━━━━━━━━ 44/44 1.2it/s 37.4s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.5s1.1ss
#                    all        199        204      0.649      0.668      0.735      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/15         0G      1.027     0.9506      1.289          8        224: 100% ━━━━━━━━━━━━ 44/44 1.1it/s 38.4s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.9s1.2ss
#                    all        199        204       0.76      0.758      0.825       0.53
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/15         0G     0.9894     0.8273       1.26          8        224: 100% ━━━━━━━━━━━━ 44/44 1.0s/it 44.9s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.5s1.2ss
#                    all        199        204      0.775       0.73      0.818      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/15         0G     0.9253     0.7599      1.232          8        224: 100% ━━━━━━━━━━━━ 44/44 1.2it/s 37.2s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.9s1.2ss
#                    all        199        204      0.765      0.829      0.858      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/15         0G     0.9307     0.6952      1.213          8        224: 100% ━━━━━━━━━━━━ 44/44 1.1it/s 39.3s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1s/it 7.5s1.3ss
#                    all        199        204      0.808      0.787      0.865      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/15         0G     0.8935     0.6347      1.202         11        224: 100% ━━━━━━━━━━━━ 44/44 1.0it/s 43.2s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.9s1.1ss
#                    all        199        204      0.824      0.815      0.891      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/15         0G     0.8612     0.5857      1.183          8        224: 100% ━━━━━━━━━━━━ 44/44 1.1it/s 38.6s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.6s1.2ss
#                    all        199        204      0.883      0.764      0.908      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/15         0G     0.8621     0.5753      1.166          8        224: 100% ━━━━━━━━━━━━ 44/44 1.0it/s 42.7s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.7s1.2ss
#                    all        199        204      0.858      0.828      0.891      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/15         0G     0.8145     0.5255      1.146          8        224: 100% ━━━━━━━━━━━━ 44/44 1.1it/s 38.9s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.1s1.1ss
#                    all        199        204      0.844      0.864      0.906      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/15         0G     0.7899     0.4892      1.117          8        224: 100% ━━━━━━━━━━━━ 44/44 1.2it/s 36.2s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6s/it 11.2s2.0s
#                    all        199        204      0.859      0.868      0.911      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/15         0G     0.7767     0.4825      1.119          9        224: 100% ━━━━━━━━━━━━ 44/44 1.1s/it 47.0s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0s/it 7.1s1.2ss
#                    all        199        204      0.885      0.844       0.92      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/15         0G     0.7504     0.4589      1.114          8        224: 100% ━━━━━━━━━━━━ 44/44 1.1it/s 40.9s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1s/it 7.7s1.3ss
#                    all        199        204      0.875      0.849      0.917      0.615
#
# 15 epochs completed in 0.216 hours.
# Optimizer stripped from /home/aadit/FAI/final/Realtime-Phobia-Filter/runs/detect/phobia-detector/insect_finetune/weights/last.pt, 25.8MB
# Optimizer stripped from /home/aadit/FAI/final/Realtime-Phobia-Filter/runs/detect/phobia-detector/insect_finetune/weights/best.pt, 25.8MB
#
# Validating /home/aadit/FAI/final/Realtime-Phobia-Filter/runs/detect/phobia-detector/insect_finetune/weights/best.pt...
# Ultralytics 8.4.21 🚀 Python-3.12.3 torch-2.10.0+cu128 CPU (Intel Core Ultra 7 256V)
# YOLOv8s-worldv2 summary (fused): 88 layers, 12,749,288 parameters, 0 gradients, 34.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.2s/it 15.1s1.5ss
#                    all        199        204      0.906       0.83       0.92      0.618
#              army worm         16         16      0.933      0.875       0.97      0.767
#  legume blister beetle         26         26          1      0.746       0.86      0.425
#             red spider         19         19       0.85      0.894      0.923       0.51
#        rice gall midge         22         22      0.849      0.636      0.859      0.423
#       rice leaf roller         23         23      0.982      0.826      0.957      0.759
#        rice leafhopper         20         23      0.776      0.826       0.87      0.614
#      rice water weevil         18         18      0.974          1      0.995       0.69
#     wheat phloeothrips         16         16      0.771      0.812      0.872      0.553
# white backed plant hopper         26         27          1      0.759      0.965      0.692
#      yellow rice borer         13         14      0.924      0.929      0.929      0.747
# Speed: 0.8ms preprocess, 59.0ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/aadit/FAI/final/Realtime-Phobia-Filter/runs/detect/phobia-detector/insect_finetune
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
#  View run <strong style="color:#cdcd00">fanciful-silence-3</strong> at: <a href='https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld/runs/79n6m682' target="_blank">https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld/runs/79n6m682</a><br> View project at: <a href='https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld' target="_blank">https://wandb.ai/engineer-a-northeastern-university/phobia-detector-yoloworld</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260313_150543-79n6m682/logs</code>

# %%
from ultralytics import YOLOWorld
model = YOLOWorld('runs/detect/phobia-detector/insect_finetune/weights/best.pt')

results = model.predict("insects-2/test/images/12_jpg.rf.6affb17d7f00774bb740b8c37b4234b0.jpg")
results[0].show()
# Out:
# image 1/1 /home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/test/images/12_jpg.rf.6affb17d7f00774bb740b8c37b4234b0.jpg: 224x224 1 rice water weevil, 2036.4ms
# Speed: 1.6ms preprocess, 2036.4ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 224)
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
import cv2
import collections

cap = cv2.VideoCapture('videoplayback.mp4')
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS)) 

out = cv2.VideoWriter('robust_blur.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))

# --- IMPROVED PERSISTENCE SETTINGS ---
last_known_boxes = {}
frames_since_seen = collections.defaultdict(int) 
persistence_limit = 20  # Increased for safety
base_pad = 25           # Larger initial padding

while cap.isOpened():
    success, frame = cap.read()
    if not success: break

    # Lowered confidence significantly; the tracker will handle the noise
    results = model.track(frame, persist=True, conf=0.15, imgsz=640, device='cpu')
    
    current_frame_ids = []
    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        ids = results[0].boxes.id.cpu().numpy().astype(int)
        for box, obj_id in zip(boxes, ids):
            last_known_boxes[obj_id] = box
            frames_since_seen[obj_id] = 0
            current_frame_ids.append(obj_id)

    for obj_id in list(last_known_boxes.keys()):
        if frames_since_seen[obj_id] < persistence_limit:
            x1, y1, x2, y2 = map(int, last_known_boxes[obj_id])
            
            # DYNAMIC PADDING: Box grows as it gets "older" to ensure coverage
            growth_factor = frames_since_seen[obj_id] * 5
            curr_pad = base_pad + growth_factor
            
            x1 = max(0, x1 - curr_pad)
            y1 = max(0, y1 - curr_pad)
            x2 = min(w, x2 + curr_pad)
            y2 = min(h, y2 + curr_pad)

            roi = frame[y1:y2, x1:x2]
            if roi.size > 0:
                # Use a larger kernel for a more "opaque" blur
                frame[y1:y2, x1:x2] = cv2.GaussianBlur(roi, (101, 101), 0)
            
            if obj_id not in current_frame_ids:
                frames_since_seen[obj_id] += 1
        else:
            del last_known_boxes[obj_id]
            del frames_since_seen[obj_id]

    out.write(frame)

cap.release()
out.release()
print("Video saved as robust_blur.mp4")
# Out:
# 0: 384x640 1 army worm, 1101.0ms
# Speed: 80.9ms preprocess, 1101.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 182.3ms
# Speed: 1.0ms preprocess, 182.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.6ms
# Speed: 0.9ms preprocess, 148.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.5ms
# Speed: 1.2ms preprocess, 156.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 171.8ms
# Speed: 0.9ms preprocess, 171.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 184.5ms
# Speed: 1.0ms preprocess, 184.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 219.8ms
# Speed: 1.0ms preprocess, 219.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 189.3ms
# Speed: 3.2ms preprocess, 189.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 237.0ms
# Speed: 2.9ms preprocess, 237.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 183.9ms
# Speed: 1.2ms preprocess, 183.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 204.1ms
# Speed: 0.8ms preprocess, 204.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 141.6ms
# Speed: 1.0ms preprocess, 141.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 146.8ms
# Speed: 0.8ms preprocess, 146.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 151.5ms
# Speed: 0.9ms preprocess, 151.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rice water weevil, 138.7ms
# Speed: 1.0ms preprocess, 138.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rice water weevil, 133.3ms
# Speed: 0.9ms preprocess, 133.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rice water weevil, 136.8ms
# Speed: 0.9ms preprocess, 136.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rice water weevil, 134.3ms
# Speed: 1.0ms preprocess, 134.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rice water weevil, 147.2ms
# Speed: 1.2ms preprocess, 147.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.5ms
# Speed: 1.2ms preprocess, 166.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.5ms
# Speed: 0.9ms preprocess, 146.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 156.4ms
# Speed: 1.9ms preprocess, 156.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 165.0ms
# Speed: 3.4ms preprocess, 165.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.8ms
# Speed: 1.6ms preprocess, 152.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 137.5ms
# Speed: 0.8ms preprocess, 137.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 133.0ms
# Speed: 0.9ms preprocess, 133.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.8ms
# Speed: 0.8ms preprocess, 160.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 134.6ms
# Speed: 0.9ms preprocess, 134.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 wheat phloeothrips, 134.5ms
# Speed: 2.1ms preprocess, 134.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 144.3ms
# Speed: 0.9ms preprocess, 144.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 176.1ms
# Speed: 1.0ms preprocess, 176.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 266.3ms
# Speed: 1.0ms preprocess, 266.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 153.3ms
# Speed: 1.0ms preprocess, 153.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 161.1ms
# Speed: 0.8ms preprocess, 161.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 193.8ms
# Speed: 1.2ms preprocess, 193.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 159.3ms
# Speed: 1.2ms preprocess, 159.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 158.8ms
# Speed: 1.2ms preprocess, 158.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 211.8ms
# Speed: 1.1ms preprocess, 211.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 153.7ms
# Speed: 0.9ms preprocess, 153.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 185.2ms
# Speed: 3.2ms preprocess, 185.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 193.0ms
# Speed: 2.3ms preprocess, 193.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 180.7ms
# Speed: 1.9ms preprocess, 180.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.9ms
# Speed: 1.4ms preprocess, 146.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 220.2ms
# Speed: 1.1ms preprocess, 220.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 159.8ms
# Speed: 1.0ms preprocess, 159.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm, 256.2ms
# Speed: 3.1ms preprocess, 256.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 army worm,
7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 legume blister beetle, 175.6ms
# Speed: 1.1ms preprocess, 175.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 185.2ms
# Speed: 1.3ms preprocess, 185.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.4ms
# Speed: 0.9ms preprocess, 166.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.8ms
# Speed: 1.0ms preprocess, 160.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.0ms
# Speed: 1.1ms preprocess, 164.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 228.7ms
# Speed: 1.0ms preprocess, 228.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 283.6ms
# Speed: 0.9ms preprocess, 283.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 186.9ms
# Speed: 2.0ms preprocess, 186.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.3ms
# Speed: 1.0ms preprocess, 174.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 190.2ms
# Speed: 1.1ms preprocess, 190.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Video saved as robust_blur.mp4

# %%
from ultralytics import YOLOWorld

# 1. Load your fine-tuned PyTorch model
model = YOLOWorld('runs/detect/phobia-detector/insect_finetune/weights/best.pt')

# 2. Export to OpenVINO format
# imgsz: Must match what you want to use in the final app (e.g., 640)
# half: True converts to FP16, which is the "sweet spot" for Intel Arc
model.export(format='openvino', imgsz=640, half=True)
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.3 torch-2.10.0+xpu CPU (Intel Core Ultra 7 256V)
# WARNING ⚠️ YOLOWorld (original version) export is not supported to any format. YOLOWorldv2 models (i.e. 'yolov8s-worldv2.pt') only support export to (torchscript, onnx, openvino, engine, coreml) formats. See https://docs.ultralytics.com/models/yolo-world for details.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLOv8s-worldv2 summary (fused): 88 layers, 12,749,288 parameters, 0 gradients, 34.2 GFLOPs
#
# PyTorch: starting from 'runs/detect/phobia-detector/insect_finetune/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (24.6 MB)
# requirements: Ultralytics requirement ['openvino>=2024.0.0'] not found, attempting AutoUpdate...
# Collecting openvino>=2024.0.0
#   Downloading openvino-2026.0.0-20965-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy<2.5.0,>=1.16.6 in ./.venv/lib/python3.12/site-packages (from openvino>=2024.0.0) (2.4.3)
# Collecting openvino-telemetry>=2023.2.1 (from openvino>=2024.0.0)
#   Downloading openvino_telemetry-2025.2.0-py3-none-any.whl.metadata (2.3 kB)
# Downloading openvino-2026.0.0-20965-cp312-cp312-manylinux_2_28_x86_64.whl (53.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/53.4 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/53.4 MB 1.6 MB/s eta 0:00:34
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/53.4 MB 1.9 MB/s eta 0:00:29
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/53.4 MB 2.0 MB/s eta 0:00:27
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/53.4 MB 2.0 MB/s eta 0:00:27
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/53.4 MB 2.0 MB/s eta 0:00:27
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/53.4 MB 2.0 MB/s eta 0:00:27
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/53.4 MB 1.7 MB/s eta 0:00:32
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/53.4 MB 1.7 MB/s eta 0:00:31
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.6/53.4 MB 1.8 MB/s eta 0:00:29
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.7/53.4 MB 1.9 MB/s eta 0:00:28
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.8/53.4 MB 2.0 MB/s eta 0:00:27
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.9/53.4 MB 1.9 MB/s eta 0:00:29
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/53.4 MB 1.9 MB/s eta 0:00:27
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/53.4 MB 2.0 MB/s eta 0:00:26
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/53.4 MB 2.1 MB/s eta 0:00:26
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/53.4 MB 2.2 MB/s eta 0:00:25
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/53.4 MB 2.2 MB/s eta 0:00:24
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/53.4 MB 2.3 MB/s eta 0:00:23
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/53.4 MB 2.4 MB/s eta 0:00:22
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/53.4 MB 2.4 MB/s eta 0:00:22
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/53.4 MB 2.5 MB/s eta 0:00:21
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2
8s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# OpenVINO: starting export with openvino 2026.0.0-20965-c6d6a13a886-releases/2026/0...
# OpenVINO: export success ✅ 24.7s, saved as 'runs/detect/phobia-detector/insect_finetune/weights/best_openvino_model/' (24.2 MB)
#
# Export complete (25.6s)
# Results saved to /home/aadit/FAI/final/Realtime-Phobia-Filter/runs/detect/phobia-detector/insect_finetune/weights
# Predict:         yolo predict task=detect model=runs/detect/phobia-detector/insect_finetune/weights/best_openvino_model imgsz=640 half
# Validate:        yolo val task=detect model=runs/detect/phobia-detector/insect_finetune/weights/best_openvino_model imgsz=640 data=insects-2/data.yaml half
# Visualize:       https://netron.app
# 'runs/detect/phobia-detector/insect_finetune/weights/best_openvino_model'

# %%
from ultralytics import YOLO
# Load the OpenVINO folder instead of the .pt file
# The library will automatically detect the .xml/.bin files inside
ov_model = YOLO('runs/detect/phobia-detector/insect_finetune/weights/best_openvino_model/')

# Run inference - it will automatically use your Arc GPU if drivers are ready
results = ov_model.predict('insects-2/test/images/12_jpg.rf.6affb17d7f00774bb740b8c37b4234b0.jpg', imgsz=640)
results[0].show()
# Out:
# Loading runs/detect/phobia-detector/insect_finetune/weights/best_openvino_model/ for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference on (CPU)...
#
# image 1/1 /home/aadit/FAI/final/Realtime-Phobia-Filter/insects-2/test/images/12_jpg.rf.6affb17d7f00774bb740b8c37b4234b0.jpg: 640x640 2 legume blister beetles, 764.4ms
# Speed: 30.8ms preprocess, 764.4ms inference, 73.2ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ## Video Blur with OpenVINO

# %%
import cv2
import collections

cap = cv2.VideoCapture('yellowriceborer.mp4')
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS)) 

out = cv2.VideoWriter('riceborerblur.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))

# --- PERSISTENCE SETTINGS ---
# Stores the last known box for each insect ID {id: [x1, y1, x2, y2]}
last_known_boxes = {} 
# How many frames to keep blurring after the bug is lost (e.g., 5 frames)
persistence_limit = 5 
# Track how many frames ago we saw each ID
frames_since_seen = collections.defaultdict(int) 

while cap.isOpened():
    success, frame = cap.read()
    if not success: break

    # 2. Run Tracking (Persist=True is key)
    # Lowering conf slightly to 0.2 since we are using a tracker to filter noise
    results = ov_model.track(frame, persist=True, conf=0.2, imgsz=640, device='cpu')

    current_frame_ids = []

    for r in results:
        if r.boxes is not None and r.boxes.id is not None:
            boxes = r.boxes.xyxy.cpu().numpy()
            ids = r.boxes.id.cpu().numpy().astype(int)

            for box, obj_id in zip(boxes, ids):
                last_known_boxes[obj_id] = box
                frames_since_seen[obj_id] = 0
                current_frame_ids.append(obj_id)

    # 3. Process All Active Blurs (Actual detections + Persistent "ghost" boxes)
    for obj_id in list(last_known_boxes.keys()):
        if frames_since_seen[obj_id] < persistence_limit:
            x1, y1, x2, y2 = map(int, last_known_boxes[obj_id])
            
            # --- IMPROVEMENT: PADDING ---
            # Make the blur 20% larger than the box to catch legs/motion
            pad = 20
            x1, y1 = max(0, x1 - pad), max(0, y1 - pad)
            x2, y2 = min(w, x2 + pad), min(h, y2 + pad)

            # Apply Blur
            roi = frame[y1:y2, x1:x2]
            if roi.size > 0:
                frame[y1:y2, x1:x2] = cv2.GaussianBlur(roi, (99, 99), 0)
            
            # Increment the counter if we didn't see it this frame
            if obj_id not in current_frame_ids:
                frames_since_seen[obj_id] += 1
        else:
            # Clean up old data
            del last_known_boxes[obj_id]
            del frames_since_seen[obj_id]

    out.write(frame)

cap.release()
out.release()
print("Video saved as robust_blur.mp4")
# Out:
# 0: 640x640 (no detections), 58.2ms
# Speed: 38.2ms preprocess, 58.2ms inference, 33.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 41.2ms
# Speed: 81.3ms preprocess, 41.2ms inference, 35.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 28.3ms
# Speed: 34.5ms preprocess, 28.3ms inference, 34.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 22.5ms
# Speed: 25.7ms preprocess, 22.5ms inference, 31.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 45.1ms
# Speed: 34.7ms preprocess, 45.1ms inference, 38.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.9ms
# Speed: 31.1ms preprocess, 26.9ms inference, 31.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 40.8ms
# Speed: 30.7ms preprocess, 40.8ms inference, 35.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 33.1ms
# Speed: 31.9ms preprocess, 33.1ms inference, 49.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 19.0ms
# Speed: 20.4ms preprocess, 19.0ms inference, 26.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 23.7ms
# Speed: 7.8ms preprocess, 23.7ms inference, 26.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 19.3ms
# Speed: 21.2ms preprocess, 19.3ms inference, 23.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.1ms
# Speed: 7.6ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.8ms
# Speed: 6.3ms preprocess, 13.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.7ms
# Speed: 3.8ms preprocess, 17.7ms inference, 12.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.8ms
# Speed: 2.5ms preprocess, 13.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.1ms
# Speed: 8.4ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.8ms
# Speed: 2.8ms preprocess, 15.8ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.4ms
# Speed: 1.5ms preprocess, 14.4ms inference, 15.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.6ms
# Speed: 1.5ms preprocess, 14.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.6ms
# Speed: 2.1ms preprocess, 11.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.3ms
# Speed: 3.6ms preprocess, 17.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.0ms
# Speed: 2.5ms preprocess, 18.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.4ms
# Speed: 6.0ms preprocess, 12.4ms inference, 15.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.2ms
# Speed: 3.8ms preprocess, 15.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.6ms
# Speed: 3.8ms preprocess, 13.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.5ms
# Speed: 5.4ms preprocess, 14.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.7ms
# Speed: 1.5ms preprocess, 11.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.5ms
# Speed: 1.6ms preprocess, 12.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 20.6ms
# Speed: 1.5ms preprocess, 20.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.8ms
# Speed: 1.5ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.0ms
# Speed: 1.6ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.5ms
# Speed: 1.5ms preprocess, 16.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.5ms
# Speed: 4.1ms preprocess, 12.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.7ms
# Speed: 3.3ms preprocess, 11.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.2ms
# Speed: 8.1ms preprocess, 14.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 yellow rice borers, 12.3ms
# Speed: 3.3ms preprocess, 12.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 10.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 22.6ms
# Speed: 16.0ms preprocess, 22.6ms inference, 38.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.2ms
# Speed: 9.7ms preprocess, 17.2ms inference, 48.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.0ms
# Speed: 5.0ms preprocess, 14.0ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.5ms
# Speed: 1.7ms preprocess, 17.5ms inference, 15.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.8ms
# Speed: 4.9ms preprocess, 18.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.4ms
# Speed: 1.7ms preprocess, 12.4ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.0ms
# Speed: 6.6ms preprocess, 11.0ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.6ms
# Speed: 4.4ms preprocess, 13.6ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 yellow rice borers, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.0ms
# Speed: 1.6ms preprocess, 15.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.2ms
# Speed: 1.7ms preprocess, 14.2ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 21.5ms
# Speed: 10.9ms preprocess, 21.5ms inference, 19.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.0ms
# Speed: 8.4ms preprocess, 16.0ms inference, 19.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.5ms
# Speed: 11.0ms preprocess, 14.5ms inference, 11.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.3ms
# Speed: 1.6ms preprocess, 16.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.9ms
# Speed: 2.7ms preprocess, 14.9ms inference, 16.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.6ms
# Speed: 2.1ms preprocess, 17.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.3ms
# Speed: 4.1ms preprocess, 13.3ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.3ms
# Speed: 2.8ms preprocess, 15.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.4ms
# Speed: 5.0ms preprocess, 16.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.1ms
# Speed: 1.5ms preprocess, 12.1ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 yellow rice borers, 12.6ms
# Speed: 1.6ms preprocess, 12.6ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.7ms
# Speed: 1.8ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 20.5ms
# Speed: 4.6ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.6ms
# Speed: 5.2ms preprocess, 17.6ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.4ms
# Speed: 1.7ms preprocess, 14.4ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.3ms
# Speed: 2.5ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.2ms
# Speed: 1.7ms preprocess, 15.2ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.3ms
# Speed: 8.6ms preprocess, 13.3ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.6ms
# Speed: 1.5ms preprocess, 17.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.4ms
# Speed: 3.5ms preprocess, 15.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.6ms
# Speed: 1.9ms preprocess, 17.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.4ms
# Speed: 2.9ms preprocess, 15.4ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.9ms
# Speed: 3.9ms preprocess, 14.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.3ms
# Speed: 1.8ms preprocess, 13.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.8ms
# Speed: 2.1ms preprocess, 12.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.3ms
# Speed: 1.9ms preprocess, 18.3ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.1ms
# Speed: 1.6ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.6ms
# Speed: 6.5ms preprocess, 13.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.2ms
# Speed: 1.7ms preprocess, 17.2ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.0ms
# Speed: 1.6ms preprocess, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.0ms
# Speed: 1.9ms preprocess, 15.0ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.2ms
# Speed: 4.8ms preprocess, 14.2ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.1ms
# Speed: 2.8ms preprocess, 17.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 17.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.0ms
# Speed: 19.0ms preprocess, 16.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.1ms
# Speed: 2.1ms preprocess, 14.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.6ms
# Speed: 1.6ms preprocess, 13.6ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.3ms
# Speed: 1.7ms preprocess, 11.3ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.6ms
# Speed: 1.9ms preprocess, 11.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.4ms
# Speed: 1.6ms preprocess, 12.4ms inference, 9.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.0ms
# Speed: 1.5ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.1ms
# Speed: 5.9ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.7ms
# Speed: 2.3ms preprocess, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.4ms
# Speed: 5.5ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.3ms
# Speed: 2.7ms preprocess, 17.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.2ms
# Speed: 1.8ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.5ms
# Speed: 9.5ms preprocess, 11.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.7ms
# Speed: 1.5ms preprocess, 12.7ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.7ms
# Speed: 2.6ms preprocess, 12.7ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 20.5ms
# Speed: 1.9ms preprocess, 20.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.5ms
# Speed: 5.5ms preprocess, 13.5ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.6ms
# Speed: 2.1ms preprocess, 13.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.1ms
# Speed: 1.6ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.2ms
# Speed: 2.5ms preprocess, 15.2ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.6ms
# Speed: 4.6ms preprocess, 11.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.7ms
# Speed: 1.5ms preprocess, 14.7ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.4ms
# Speed: 1.5ms preprocess, 12.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 16.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.4ms
# Speed: 1.7ms preprocess, 12.4ms inference, 9.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.5ms
# Speed: 1.7ms preprocess, 15.5ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.7ms
# Speed: 1.8ms preprocess, 14.7ms inference, 9.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.9ms
# Speed: 1.9ms preprocess, 16.9ms inference, 9.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 20.3ms
# Speed: 2.1ms preprocess, 20.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.2ms
# Speed: 1.7ms preprocess, 14.2ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.8ms
# Speed: 2.8ms preprocess, 13.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.4ms
# Speed: 3.5ms preprocess, 15.4ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.3ms
# Speed: 3.5ms preprocess, 15.3ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.3ms
# Speed: 2.8ms preprocess, 13.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.3ms
# Speed: 1.9ms preprocess, 16.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.8ms
# Speed: 1.8ms preprocess, 14.8ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.7ms
# Speed: 1.7ms preprocess, 13.7ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.9ms
# Speed: 2.8ms preprocess, 13.9ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.2ms
# Speed: 1.8ms preprocess, 14.2ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.9ms
# Speed: 1.7ms preprocess, 14.9ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.1ms
# Speed: 1.6ms preprocess, 15.1ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 11.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.2ms
# Speed: 3.3ms preprocess, 16.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.7ms
# Speed: 1.6ms preprocess, 14.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.8ms
# Speed: 2.4ms preprocess, 15.8ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.2ms
# Speed: 4.1ms preprocess, 12.2ms inference, 11.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.8ms
# Speed: 3.4ms preprocess, 12.8ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.1ms
# Speed: 2.7ms preprocess, 15.1ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.8ms
# Speed: 6.2ms preprocess, 16.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.3ms
# Speed: 1.8ms preprocess, 16.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.7ms
# Speed: 2.5ms preprocess, 15.7ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.5ms
# Speed: 1.7ms preprocess, 12.5ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 20.0ms
# Speed: 4.4ms preprocess, 20.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 21.4ms
# Speed: 1.7ms preprocess, 21.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.5ms
# Speed: 1.8ms preprocess, 14.5ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 18.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.2ms
# Speed: 3.3ms preprocess, 13.2ms inference, 9.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.9ms
# Speed: 1.7ms preprocess, 13.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.1ms
# Speed: 2.8ms preprocess, 13.1ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.4ms
# Speed: 3.9ms preprocess, 16.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.7ms
# Speed: 5.4ms preprocess, 15.7ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.4ms
# Speed: 1.7ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.7ms
# Speed: 4.0ms preprocess, 13.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.9ms
# Speed: 1.6ms preprocess, 13.9ms inference, 11.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.8ms
# Speed: 1.6ms preprocess, 17.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.0ms
# Speed: 2.5ms preprocess, 15.0ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.2ms
# Speed: 2.5ms preprocess, 15.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.8ms
# Speed: 4.9ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.7ms
# Speed: 5.1ms preprocess, 14.7ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 20.8ms
# Speed: 1.6ms preprocess, 20.8ms inference, 13.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.0ms
# Speed: 4.3ms preprocess, 18.0ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 11.7ms
# Speed: 2.6ms preprocess, 11.7ms inference, 13.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.5ms
# Speed: 1.8ms preprocess, 16.5ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.8ms
# Speed: 2.5ms preprocess, 14.8ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.3ms
# Speed: 2.8ms preprocess, 14.3ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.0ms
# Speed: 1.8ms preprocess, 14.0ms inference, 9.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.3ms
# Speed: 1.6ms preprocess, 14.3ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.2ms
# Speed: 1.6ms preprocess, 14.2ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.7ms
# Speed: 1.6ms preprocess, 14.7ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.2ms
# Speed: 1.7ms preprocess, 14.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.3ms
# Speed: 7.6ms preprocess, 14.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.1ms
# Speed: 3.7ms preprocess, 14.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.9ms
# Speed: 3.1ms preprocess, 17.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 yellow rice borers, 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 20.8ms
# Speed: 2.6ms preprocess, 20.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.4ms
# Speed: 1.8ms preprocess, 14.4ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 25.0ms
# Speed: 16.3ms preprocess, 25.0ms inference, 20.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 24.4ms
# Speed: 20.3ms preprocess, 24.4ms inference, 21.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 23.0ms
# Speed: 10.6ms preprocess, 23.0ms inference, 14.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.6ms
# Speed: 2.6ms preprocess, 17.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 20.0ms
# Speed: 3.8ms preprocess, 20.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 yellow rice borers, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 27.0ms
# Speed: 1.9ms preprocess, 27.0ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 18.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.2ms
# Speed: 2.7ms preprocess, 17.2ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 28.6ms
# Speed: 23.4ms preprocess, 28.6ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.6ms
# Speed: 9.1ms preprocess, 15.6ms inference, 15.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.8ms
# Speed: 12.3ms preprocess, 18.8ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 11.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.1ms
# Speed: 1.6ms preprocess, 16.1ms inference, 11.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.9ms
# Speed: 2.2ms preprocess, 15.9ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.5ms
# Speed: 3.3ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.2ms
# Speed: 3.6ms preprocess, 13.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.1ms
# Speed: 1.9ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 yellow rice borers, 14.0ms
# Speed: 1.8ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 13.6ms
# Speed: 1.9ms preprocess, 13.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 22.7ms
# Speed: 2.0ms preprocess, 22.7ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 19.7ms
# Speed: 1.7ms preprocess, 19.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 19.3ms
# Speed: 10.1ms preprocess, 19.3ms inference, 14.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.9ms
# Speed: 11.9ms preprocess, 14.9ms inference, 21.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 19.6ms
# Speed: 6.1ms preprocess, 19.6ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 14.3ms
# Speed: 1.7ms preprocess, 14.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.1ms
# Speed: 1.7ms preprocess, 17.1ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 17.0ms
# Speed: 3.7ms preprocess, 17.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.1ms
# Speed: 1.7ms preprocess, 15.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.3ms
# Speed: 3.1ms preprocess, 18.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 19.1ms
# Speed: 1.7ms preprocess, 19.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.5ms
# Speed: 16.9ms preprocess, 12.5ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.3ms
# Speed: 2.1ms preprocess, 12.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 16.2ms
# Speed: 1.7ms preprocess, 16.2ms inference, 22.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 12.9ms
# Speed: 1.6ms preprocess, 12.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 yellow rice borer, 20.1ms
# Speed: 3.2ms preprocess, 20.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Video saved as robust_blur.mp4
